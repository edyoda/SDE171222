# %%
import area

area.area_of_circle(5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19808\2008043531.py in <module>
# ----> 1 import area
#       2
#       3 area.area_of_circle(5)
#
# ModuleNotFoundError: No module named 'area'

# %%
import sys

sys.path
# Out:
# ['C:\\Users\\SHIKHA\\Downloads\\EDYODA_SHIKHA',
#  'C:\\ProgramData\\Anaconda3\\python39.zip',
#  'C:\\ProgramData\\Anaconda3\\DLLs',
#  'C:\\ProgramData\\Anaconda3\\lib',
#  'C:\\ProgramData\\Anaconda3',
#  '',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\SHIKHA\\.ipython']

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\SHIKHA\\Downloads\\EDYODA_SHIKHA'

# %% [markdown]
# # Modules:

# %% [markdown]
# - python scripts to perform a specific task

# %% [markdown]
# ![Screenshot_20230113_205324.png](attachment:Screenshot_20230113_205324.png)

# %% [markdown]
# ![Screenshot_20230113_205808.png](attachment:Screenshot_20230113_205808.png)

# %% [markdown]
# # Packages:

# %% [markdown]
# Packages:
# - it is a directory having collection of modules
#
# ex: numpy, pandas

# %% [markdown]
# ![Screenshot_20230113_210159.png](attachment:Screenshot_20230113_210159.png)
